# %% [markdown]
# # Data Analyst Capstone Project

# %% [markdown]
# # Submitted by: EKTA KUMARI

# %% [markdown]
# # Project Title: NutriCal : McDonald's Menu Nutritional Analysis

# %% [markdown]
# In a world where nutritional awareness is peramount, we delve into the heart of one of the world's most iconic fast-food menu.
# Welcome to the "McDonald's Menu Nutritional Analysis" project,
# where we systematically break down the nutritional content of menu ,
# providing you with the key insights needed to make mindful and informed dining decisions.

# %% [markdown]
# # Project Components

# %% [markdown]
# - Introduction

# %% [markdown]
# - Problem Statement

# %% [markdown]
# - Import necessory libraries

# %% [markdown]
# - Analysing and Understanding Data
#
#    - Analysing Row and Cols
#    - Analysing type of dataframe
#    - Printing all columns of dataframe
#    - Information about data columns and its type
#    - Printing of top rows

# %% [markdown]
# - Data Cleaning and Manipulation
#
#   - Checking duplicate values
#   - Checking null values

# %% [markdown]
# - Exploratory Data Analysis
#
#   - Analyze the distribution of calories counts across menu items
#   - Explore the Nutrition content of different Items

# %% [markdown]
# - Data Visualization
#
#   - Categorical Variable Analysis
#   - Numerical Variable Analysis

# %% [markdown]
# - Nutrition-Based Insights
#
#   - Identify menu items with the highest and lowest calorie counts

# %% [markdown]
# # Introduction

# %% [markdown]
# This project has meaningful Extract of information from the McDonald's menu nutritional dataset and we
# Perform exploratory data analysis to understand the nutritional distribution and trends using
#  visualizations  to present the calorie count and nutrition facts of different menu items and we have to
# Identify healthy and less healthy menu options based on nutritional content.

# %% [markdown]
# # Problem Statement

# %% [markdown]
# McDonalds Global fast-food chain is offering a diverse menu.
# As a Data analyst we need to analyse the Nutritional content of the menu item available at McDonalds outlets

# %% [markdown]
# # Import necessory libraries

# %%
# setting up my environment by loading libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Import os to check the directory structure

# %%
import os
os.listdir("D:\data")
# Out:
# ['Nutrical Dataset.csv', 'Nutrical_Dashboard.xlsx']

# %% [markdown]
# #  import data from excel file and load into df dataframe

# %%
#df=pd.read_excel("D:\data\Nutrical_Dashboard.xlsx")
df=pd.read_csv("D:\\data\\Nutrical Dataset.csv")

# %%
#checking no of rows and cols

df.shape
# Out:
# (260, 24)

# %%
#checking type of df
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Print all columns of dataframe

# %%
df.keys()
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %% [markdown]
# # Information about data columns and its data type

# %%
print("\nSummary of the dataset:")
print(df.info())
# Out:
# Summary of the dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
# Top 5 row of the dataframe

df.head()
# Out:
#     Category                              Item    Serving Size  Calories  \
# 0  Breakfast                      Egg McMuffin  4.8 oz (136 g)       300
# 1  Breakfast                 Egg White Delight  4.8 oz (135 g)       250
# 2  Breakfast                  Sausage McMuffin  3.9 oz (111 g)       370
# 3  Breakfast         Sausage McMuffin with Egg  5.7 oz (161 g)       450
# 4  Breakfast  Sausage McMuffin with Egg Whites  5.7 oz (161 g)       400
#
#    Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 0                120       13.0                         20            5.0
# 1                 70        8.0                         12            3.0
# 2                200       23.0                         35            8.0
# 3                250       28.0                         43           10.0
# 4                210       23.0                         35            8.0
#
#    Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# ...

# %%
# check duplicate value
df[df.duplicated()].count().sum()
# Out:
# 0

# %%
#checking the missing value if exists

print(df.isnull().any())
# Out:
# Category                         False
# Item                             False
# Serving Size                     False
# Calories                         False
# Calories from Fat                False
# Total Fat                        False
# Total Fat (% Daily Value)        False
# Saturated Fat                    False
# Saturated Fat (% Daily Value)    False
# Trans Fat                        False
# Cholesterol                      False
# Cholesterol (% Daily Value)      False
# Sodium                           False
# Sodium (% Daily Value)           False
# Carbohydrates                    False
# Carbohydrates (% Daily Value)    False
# Dietary Fiber                    False
# Dietary Fiber (% Daily Value)    False
# Sugars                           False
# Protein                          False
# Vitamin A (% Daily Value)        False
# Vitamin C (% Daily Value)        False
# Calcium (% Daily Value)          False
# Iron (% Daily Value)             False
# dtype: bool

# %%
#discription of data frame
df.describe()
# Out:
#           Calories  Calories from Fat   Total Fat  Total Fat (% Daily Value)  \
# count   260.000000         260.000000  260.000000                 260.000000
# mean    368.269231         127.096154   14.165385                  21.815385
# std     240.269886         127.875914   14.205998                  21.885199
# min       0.000000           0.000000    0.000000                   0.000000
# 25%     210.000000          20.000000    2.375000                   3.750000
# 50%     340.000000         100.000000   11.000000                  17.000000
# 75%     500.000000         200.000000   22.250000                  35.000000
# max    1880.000000        1060.000000  118.000000                 182.000000
#
#        Saturated Fat  Saturated Fat (% Daily Value)   Trans Fat  Cholesterol  \
# count     260.000000                     260.000000  260.000000   260.000000
# mean        6.007692                      29.965385    0.203846    54.942308
# ...

# %%
print(df['Category'].unique())
# Out:
# ['Breakfast' 'Beef & Pork' 'Chicken & Fish' 'Salads' 'Snacks & Sides'
#  'Desserts' 'Beverages' 'Coffee & Tea' 'Smoothies & Shakes']

# %%
print(df['Item'].unique())
# Out:
# ['Egg McMuffin' 'Egg White Delight' 'Sausage McMuffin'
#  'Sausage McMuffin with Egg' 'Sausage McMuffin with Egg Whites'
#  'Steak & Egg McMuffin' 'Bacon, Egg & Cheese Biscuit (Regular Biscuit)'
#  'Bacon, Egg & Cheese Biscuit (Large Biscuit)'
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Regular Biscuit)'
#  'Bacon, Egg & Cheese Biscuit with Egg Whites (Large Biscuit)'
#  'Sausage Biscuit (Regular Biscuit)' 'Sausage Biscuit (Large Biscuit)'
#  'Sausage Biscuit with Egg (Regular Biscuit)'
#  'Sausage Biscuit with Egg (Large Biscuit)'
#  'Sausage Biscuit with Egg Whites (Regular Biscuit)'
#  'Sausage Biscuit with Egg Whites (Large Biscuit)'
#  'Southern Style Chicken Biscuit (Regular Biscuit)'
#  'Southern Style Chicken Biscuit (Large Biscuit)'
#  'Steak & Egg Biscuit (Regular Biscuit)' 'Bacon, Egg & Cheese McGriddles'
#  'Bacon, Egg & Cheese McGriddles with Egg Whites' 'Sausage McGriddles'
#  'Sausage, Egg & Cheese McGriddles'
#  'Sausage, Egg & Cheese McGriddles with Egg Whites'
# ...

# %%
max_values = df[['Calories','Total Fat','Carbohydrates', 'Dietary Fiber', 'Sugars', 'Protein', 'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)','Calcium (% Daily Value)','Iron (% Daily Value)']].max()

print(max_values)
# Out:
# Calories                     1880.0
# Total Fat                     118.0
# Carbohydrates                 141.0
# Dietary Fiber                   7.0
# Sugars                        128.0
# Protein                        87.0
# Vitamin A (% Daily Value)     170.0
# Vitamin C (% Daily Value)     240.0
# Calcium (% Daily Value)        70.0
# Iron (% Daily Value)           40.0
# dtype: float64

# %% [markdown]
# # Pie chart for values count in each Category

# %%
df.Category.value_counts().plot.pie(colors = ['lightcoral','lightgreen','pink','orange','brown','gray','blue','red','yellow'],
                                    wedgeprops={"linewidth":1,"edgecolor":"black"}, radius=1.2)
plt.show()

# %% [markdown]
# # Category and Quantity wise Bar Chart

# %%
def barplot(variable):
    var=df[variable]
    varval=var.value_counts()
    plt.figure(figsize=(10,3))
    plt.bar(varval.index,varval)
    plt.xticks(rotation=45,ha='right')
    plt.xticks(varval.index,varval.index.values)
    plt.ylabel("Friquency")
    plt.title(variable)
    plt.show()
    
categories=["Category"]
for a in categories:
    barplot(a)

# %% [markdown]
# # Checking for outliers in data

# %%
plt.figure(figsize=(15,12))
plt.subplot(3,1,1)
sns.boxplot(x=df['Calories'],color='lightcoral')

plt.subplot(3,1,2)
sns.boxplot(x=df['Calories from Fat'],color='lightcoral')

plt.subplot(3,1,3)
sns.boxplot(x=df['Cholesterol'],color='lightcoral')

plt.show()

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %% [markdown]
# # Examine the calorie distribution

# %%
mean_calories = df['Calories'].mean()
median_calories = df['Calories'].median()
mode_calories = df['Calories'].mode().values[0]
std_calories = df['Calories'].std()

print(f"Mean: {mean_calories}")
print(f"Median: {median_calories}")
print(f"Mode: {mode_calories}")
print(f"Standard Deviation: {std_calories}")
# Out:
# Mean: 368.2692307692308
# Median: 340.0
# Mode: 0
# Standard Deviation: 240.26988649145852

# %% [markdown]
# # Explore the Nutritional content of different items

# %%
nutritional_columns = ['Total Fat', 'Protein', 'Carbohydrates']

nutritional_stats = df[nutritional_columns].describe()
print(nutritional_stats)
# Out:
#         Total Fat     Protein  Carbohydrates
# count  260.000000  260.000000     260.000000
# mean    14.165385   13.338462      47.346154
# std     14.205998   11.426146      28.252232
# min      0.000000    0.000000       0.000000
# 25%      2.375000    4.000000      30.000000
# 50%     11.000000   12.000000      44.000000
# 75%     22.250000   19.000000      60.000000
# max    118.000000   87.000000     141.000000

# %%
#Correlation matrix
correlation_matrix = df[nutritional_columns].corr()

#Heatmap
plt.figure(figsize=(10,6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Matrix of Nutritional Content')
plt.show()

# %% [markdown]
# # Visualising calorie distribution and nutritional content

# %%
#Generate  a bar chart to illustrate the distribution of calories by category
plt.figure(figsize=(10,7))
sns.barplot(x='Category', y='Calories', data=df)
plt.title('Calorie Distribution by Category')
plt.xlabel('Category')
plt.ylabel('Calories')
plt.xticks(rotation=45,ha='right')
plt.show()

# %% [markdown]
# # Box Plot For Calorie Count Distribution Across Categories

# %%
plt.figure(figsize=(10,3))
sns.boxplot(x='Category',y='Calories',data=df, palette='viridis')
plt.title('Box Plot of Calorie Count Distribution Across Categories')
plt.xlabel('Categories')
plt.ylabel('Calorie Counts')
plt.xticks(rotation=45,ha='right')
plt.show()

# %%
#Summation
#In terms of serving size and calorie count, chicken and fish display the highest calorie content

# %% [markdown]
# # Visualising the distribution of calories

# %%
#Creat histogram to visualize
plt.figure(figsize=(9,5))
sns.histplot(data=df["Calories"], bins=20)
plt.title("Distribution of Calorie Counts across the Menu Items")
plt.xlabel('Calories')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# # Visualising the distribution of Nutritional Content

# %%
nutritional_columns = ['Total Fat','Protein','Carbohydrates']

plt.figure(figsize=(10,6))
sns.boxplot(data=df[nutritional_columns])
plt.title('Distribution of Nutritional Content')
plt.ylabel('Grams')
plt.show()

# %% [markdown]
# # Examine and compare the nutritional characteristics across different food categories

# %%
#Filter data for specific categories
selected_categories = ['Desserts','Salads','Burgers']
df_selected_categories = df[df['Category'].isin(selected_categories)]

#Display basic statistics for each category
category_stats = df_selected_categories.groupby('Category').describe()

#Create bar charts to compare nutritional characteristics
nutritional_columns = ['Total Fat', 'Protein', 'Carbohydrates']

for nutrient in nutritional_columns:
    plt.figure(figsize=(5,3))
    sns.barplot(x='Category',y=nutrient, data=df_selected_categories)
    plt.title(f'{nutrient} Content in Desserts,Burgers, and  Salads')
    plt.xlabel('Category')
    plt.ylabel(f'{nutrient} (g)')
    plt.show()

# %% [markdown]
# # Determine which menu items have the highest and lowest calorie counts

# %%
highest_calories = df.nlargest(5, 'Calories')
lowest_calories = df.nsmallest(5, 'Calories')

print("Menu Items with the Highest Calorie Counts:")
print(highest_calories[['Item','Calories']])

print("\nMenu Items with the Lowest Calorie Counts:")
print(lowest_calories[['Item', 'Calories']])
# Out:
# Menu Items with the Highest Calorie Counts:
#                                                  Item  Calories
# 82                       Chicken McNuggets (40 piece)      1880
# 32        Big Breakfast with Hotcakes (Large Biscuit)      1150
# 31      Big Breakfast with Hotcakes (Regular Biscuit)      1090
# 34  Big Breakfast with Hotcakes and Egg Whites (La...      1050
# 33  Big Breakfast with Hotcakes and Egg Whites (Re...       990
#
# Menu Items with the Lowest Calorie Counts:
#                        Item  Calories
# 114       Diet Coke (Small)         0
# 115      Diet Coke (Medium)         0
# 116       Diet Coke (Large)         0
# 117       Diet Coke (Child)         0
# 122  Diet Dr Pepper (Small)         0

# %%
# Determine which menu items have the highest and lowest calorie counts
highest_calories = df.nlargest(1, 'Calories')
highest_calories
# Out:
#           Category                          Item     Serving Size  Calories  \
# 82  Chicken & Fish  Chicken McNuggets (40 piece)  22.8 oz (646 g)      1880
#
#     Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 82               1060      118.0                        182           20.0
#
#     Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 82                            101        1.0  ...            118
#
#     Carbohydrates (% Daily Value)  Dietary Fiber  \
# 82                             39              6
#
#     Dietary Fiber (% Daily Value)  Sugars  Protein  Vitamin A (% Daily Value)  \
# 82                             24       1       87                          0
#
#     Vitamin C (% Daily Value)  Calcium (% Daily Value)  Iron (% Daily Value)
# 82                         15                        8                    25
#
# [1 rows x 24 columns]

# %%
#Summation : Chicken and Fish Exhibit the Highest Caloric Content

# %%
lowest_calories = df.nsmallest(1, 'Calories')
lowest_calories
# Out:
#       Category               Item  Serving Size  Calories  Calories from Fat  \
# 114  Beverages  Diet Coke (Small)  16 fl oz cup         0                  0
#
#      Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 114        0.0                          0            0.0
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 114                              0        0.0  ...              0
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 114                              0              0
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 114                              0       0        0
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 114                          0                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 114                        0                     0
#
# [1 rows x 24 columns]

# %%
#Summation : Beverages have the lowest calorie content

# %% [markdown]
# # Comprehensive Overview

# %% [markdown]
# - Breakfast items are expected to be the healthiest on the menu. Despite McDonalds efforts to incorporate healthier options,
#   such as fruits and vegitables,there remains an imbalance in nutritional content.McDonalds should focus on reducing cholesterol
#   and sodium levels in their breakfast items.
# - Nuggets are identified as the least healthy food option, particularly due to high levels of unsaturated fat and cholesterol.
#   This could contribute to overweight issues in children who consume McDonalds regularly.
# - While people express concerns about how McDonalds may negatively impact their health, it also presents an opportunity for the
#   company to innovate and introduce new, healthier products.
# - how the nutritional analysis could benefit McDonalds customers and the organization?
#   - Nutritional analysis benefits both McDonalds customers and the organization by promoting informed choices, customer
#    satisfaction, market responsiveness, product innovation and corporate social responsibility

# %% [markdown]
# # THANK YOU
